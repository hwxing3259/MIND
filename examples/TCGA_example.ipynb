# %%
import os
import sys
import argparse
import torch
import torch.multiprocessing
import torch.nn as nn
from torch.nn.modules.module import Module
from scipy.spatial.distance import cdist
from sklearn.metrics import pairwise_distances, adjusted_rand_score, normalized_mutual_info_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tqdm.auto import tqdm

import numpy as np
import pandas as pd
import snf
from sklearn.metrics.pairwise import pairwise_kernels
from sklearn.cluster import spectral_clustering, KMeans
from sklearn.metrics import v_measure_score
import matplotlib.pyplot as plt

device = 'cuda' if torch.cuda.is_available() else 'cpu'
from MIND import MIND

# %% [markdown]
# # TCGA datasets
# We train and test the 17 multiomics TCGA dataests using the proposed model. Training/testing of the CCMA dataset is identical.
# ## Training

# %%
# specify hyperparameters
emb_dim = 64
lr = 1e-4
epoch = 5000

# %%
np.random.seed(31415)
torch.manual_seed(31415)

cancer_types = ['GBM', 'HNSC', 'LUSC', 'LIHC', 'LUAD', 'KIRC', 'BRCA', 'LGG', 'OV', 'PRAD', 'SKCM', 'THCA', 'BLCA', 'STAD', 'UCEC', 'COADREAD', 'COAD', 'CESC']  # do COAD seperately

for cancer_type in cancer_types:
    clinic_data = pd.read_csv('./TCGA_preprocessed/{}/clinic_data.csv'.format(cancer_type), header=0, index_col=0)
    RNA_data = pd.read_csv('./TCGA_preprocessed/{}/RNA_data.csv'.format(cancer_type), header=0, index_col=0)
    methyl_data = pd.read_csv('./TCGA_preprocessed/{}/meth_data.csv'.format(cancer_type), header=0, index_col=0)
    rppa_data = pd.read_csv('./TCGA_preprocessed/{}/rppa_data_imp.csv'.format(cancer_type), header=0, index_col=0)
    cna_data = pd.read_csv('./TCGA_preprocessed/{}/cna_data.csv'.format(cancer_type), header=0, index_col=0)
    if os.path.isfile('./TCGA_preprocessed/{}/miRNA_data_imp.csv'.format(cancer_type)):
        miRNA_data = pd.read_csv('./TCGA_preprocessed/{}/miRNA_data_imp.csv'.format(cancer_type), header=0, index_col=0)

    N = clinic_data.shape[0]
    print('Cancer type = {}'.format(cancer_type))
    print('total number of patients = {}'.format(N))
    if os.path.isfile('./TCGA_preprocessed/{}/miRNA_data_imp.csv'.format(cancer_type)):
        data_dict = {'RNA': RNA_data, 'methyl': methyl_data, 'CNA': cna_data, 'miRNA': miRNA_data, 'RPPA': rppa_data}
    else:
        data_dict = {'RNA': RNA_data, 'methyl': methyl_data, 'CNA': cna_data, 'RPPA': rppa_data}

    for i, j in data_dict.items():
        print('{} data missing {}/{}, missing proportion = {}'.format(i, j.iloc[:, 0].isna().sum(), j.shape[0], np.round(j.iloc[:, 0].isna().mean(), 3)))

    test = MIND(data_dict=data_dict, device=device, emb_dim=emb_dim).to(device)
    test.my_train(epoch, lr=lr)
    with torch.no_grad():
        z_emb = test.get_embedding()[0].cpu().numpy()

    if not os.path.isdir('./TCGA_results/{}'.format(cancer_type)):
        os.makedirs('./TCGA_results/{}'.format(cancer_type))

    pd.DataFrame(z_emb, index=RNA_data.index).to_csv('./TCGA_results/{}/embeddings.csv'.format(cancer_type))
# Out:
# Cancer type = GBM
# total number of patients = 590
# RNA data missing 431/590, missing proportion = 0.731
# methyl data missing 307/590, missing proportion = 0.52
# CNA data missing 19/590, missing proportion = 0.032
# RPPA data missing 353/590, missing proportion = 0.598
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = HNSC
# total number of patients = 528
# RNA data missing 7/528, missing proportion = 0.013
# methyl data missing 0/528, missing proportion = 0.0
# CNA data missing 11/528, missing proportion = 0.021
# miRNA data missing 4/528, missing proportion = 0.008
# RPPA data missing 316/528, missing proportion = 0.598
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = LUSC
# total number of patients = 504
# RNA data missing 3/504, missing proportion = 0.006
# methyl data missing 132/504, missing proportion = 0.262
# CNA data missing 17/504, missing proportion = 0.034
# miRNA data missing 26/504, missing proportion = 0.052
# RPPA data missing 176/504, missing proportion = 0.349
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = LIHC
# total number of patients = 377
# RNA data missing 6/377, missing proportion = 0.016
# methyl data missing 0/377, missing proportion = 0.0
# CNA data missing 10/377, missing proportion = 0.027
# miRNA data missing 4/377, missing proportion = 0.011
# RPPA data missing 193/377, missing proportion = 0.512
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = LUAD
# total number of patients = 520
# RNA data missing 4/520, missing proportion = 0.008
# methyl data missing 59/520, missing proportion = 0.113
# CNA data missing 9/520, missing proportion = 0.017
# miRNA data missing 7/520, missing proportion = 0.013
# RPPA data missing 155/520, missing proportion = 0.298
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = KIRC
# total number of patients = 537
# RNA data missing 4/537, missing proportion = 0.007
# methyl data missing 218/537, missing proportion = 0.406
# CNA data missing 28/537, missing proportion = 0.052
# miRNA data missing 21/537, missing proportion = 0.039
# RPPA data missing 59/537, missing proportion = 0.11
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = BRCA
# total number of patients = 1097
# RNA data missing 4/1097, missing proportion = 0.004
# methyl data missing 307/1097, missing proportion = 0.28
# CNA data missing 28/1097, missing proportion = 0.026
# miRNA data missing 19/1097, missing proportion = 0.017
# RPPA data missing 211/1097, missing proportion = 0.192
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = LGG
# total number of patients = 515
# RNA data missing 0/515, missing proportion = 0.0
# methyl data missing 0/515, missing proportion = 0.0
# CNA data missing 5/515, missing proportion = 0.01
# miRNA data missing 4/515, missing proportion = 0.008
# RPPA data missing 86/515, missing proportion = 0.167
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = OV
# total number of patients = 590
# RNA data missing 286/590, missing proportion = 0.485
# methyl data missing 13/590, missing proportion = 0.022
# CNA data missing 23/590, missing proportion = 0.039
# miRNA data missing 137/590, missing proportion = 0.232
# RPPA data missing 170/590, missing proportion = 0.288
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = PRAD
# total number of patients = 498
# RNA data missing 1/498, missing proportion = 0.002
# methyl data missing 0/498, missing proportion = 0.0
# CNA data missing 9/498, missing proportion = 0.018
# miRNA data missing 4/498, missing proportion = 0.008
# RPPA data missing 146/498, missing proportion = 0.293
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = SKCM
# total number of patients = 470
# RNA data missing 1/470, missing proportion = 0.002
# methyl data missing 0/470, missing proportion = 0.0
# CNA data missing 103/470, missing proportion = 0.219
# miRNA data missing 22/470, missing proportion = 0.047
# RPPA data missing 117/470, missing proportion = 0.249
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = THCA
# total number of patients = 503
# RNA data missing 2/503, missing proportion = 0.004
# methyl data missing 0/503, missing proportion = 0.0
# CNA data missing 6/503, missing proportion = 0.012
# miRNA data missing 1/503, missing proportion = 0.002
# RPPA data missing 281/503, missing proportion = 0.559
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = BLCA
# total number of patients = 412
# RNA data missing 4/412, missing proportion = 0.01
# methyl data missing 0/412, missing proportion = 0.0
# CNA data missing 4/412, missing proportion = 0.01
# miRNA data missing 3/412, missing proportion = 0.007
# RPPA data missing 68/412, missing proportion = 0.165
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = STAD
# total number of patients = 443
# RNA data missing 25/443, missing proportion = 0.056
# methyl data missing 48/443, missing proportion = 0.108
# CNA data missing 5/443, missing proportion = 0.011
# miRNA data missing 7/443, missing proportion = 0.016
# RPPA data missing 86/443, missing proportion = 0.194
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = UCEC
# total number of patients = 548
# RNA data missing 3/548, missing proportion = 0.005
# methyl data missing 116/548, missing proportion = 0.212
# CNA data missing 25/548, missing proportion = 0.046
# miRNA data missing 9/548, missing proportion = 0.016
# RPPA data missing 108/548, missing proportion = 0.197
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = COADREAD
# total number of patients = 626
# RNA data missing 4/626, missing proportion = 0.006
# methyl data missing 235/626, missing proportion = 0.375
# CNA data missing 36/626, missing proportion = 0.058
# miRNA data missing 77/626, missing proportion = 0.123
# RPPA data missing 137/626, missing proportion = 0.219
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = COAD
# total number of patients = 457
# RNA data missing 2/457, missing proportion = 0.004
# methyl data missing 164/457, missing proportion = 0.359
# CNA data missing 8/457, missing proportion = 0.018
# miRNA data missing 51/457, missing proportion = 0.112
# RPPA data missing 99/457, missing proportion = 0.217
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = CESC
# total number of patients = 307
# RNA data missing 3/307, missing proportion = 0.01
# methyl data missing 0/307, missing proportion = 0.0
# CNA data missing 12/307, missing proportion = 0.039
# miRNA data missing 0/307, missing proportion = 0.0
# RPPA data missing 134/307, missing proportion = 0.436
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000

# %% [markdown]
# ## Downstreaming task 1: Cancer stage classification
# We fit XGBoost classfiers to predict cancer stage of patients from the output embeddings.

# %%
from sklearn.model_selection import KFold
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
# test cancer type classification
cancer_type_subtypes = ['LUAD', 'KIRC', 'BRCA', 'LGG', 'OV', 'SKCM', 'THCA', 'BLCA', 'STAD', 'UCEC', 'COADREAD', 'COAD', 'GBM', 'HNSC', 'LUSC', 'LIHC', 'CESC']
res_ACC = pd.DataFrame(np.zeros((len(cancer_type_subtypes), 1)), index=cancer_type_subtypes, columns=['Accuracy'])

for c_type in cancer_type_subtypes:
    print(c_type)
    clinic_data = pd.read_csv('./TCGA_preprocessed/{}/clinic_data.csv'.format(c_type), header=0, index_col=0)
    if 'Stage' in clinic_data.columns:
        non_missing_subtypes_names = clinic_data.index.to_numpy()[~clinic_data['Stage'].isna()]
        stage_vec = clinic_data['Stage'].loc[non_missing_subtypes_names]
        encoder = LabelEncoder()
        labels = encoder.fit_transform(stage_vec)
        # if len(stage_vec) > 0.1*clinic_data.shape[0]:
        #     print(c_type)
        #     print(len(stage_vec)/clinic_data.shape[0])
        emb = pd.read_csv('./TCGA_results/{}/embeddings.csv'.format(c_type), index_col=0).loc[non_missing_subtypes_names]
        if emb.shape[0] > 10:
            kf = KFold(n_splits=10, shuffle=True, random_state=314159)
            acc_temp = 0.
            for train_idx, test_idx in kf.split(emb):
                X_train, X_test = emb.to_numpy()[train_idx], emb.to_numpy()[test_idx]
                y_train, y_test = labels[train_idx], labels[test_idx]
    
                model_gbm = GradientBoostingClassifier(n_estimators=150)
    
                model = xgb.XGBClassifier(
                    objective='multi:softmax',  
                    num_class=len(np.unique(labels)),
                    eval_metric='mlogloss'
                )
                model.fit(X_train, y_train)
                y_pred = model.predict(X_test)
                acc_temp += np.mean(y_pred == y_test)
            res_ACC.loc[c_type] = acc_temp/10.
        else:
            res_ACC.loc[c_type] = np.nan

    else:
        res_ACC.loc[c_type] = np.nan
print(res_ACC)
# Out:
# LUAD
# KIRC
# BRCA
# LGG
# OV
# SKCM
# THCA
# BLCA
# STAD
# UCEC
# COADREAD
# COAD
# GBM
# HNSC
# LUSC
# LIHC
# CESC
#           Accuracy
# LUAD      0.523115
# KIRC      0.517855
# BRCA      0.508270
# LGG            NaN
# OV             NaN
# SKCM      0.457491
# THCA      0.542902
# BLCA      0.460976
# STAD      0.407898
# UCEC           NaN
# COADREAD  0.346913
# COAD      0.344293
# GBM            NaN
# HNSC      0.519614
# LUSC      0.472000
# LIHC      0.481349
# CESC      0.473333

# %% [markdown]
# ## Downstreaming task 2: Survival prediction
# Here we fit Coxnet survival models to predict the survival status of patients. In addition to the output embeddings, we also add sex and age of patients to the input features. Performance is measured using C-index.

# %%
from sklearn.model_selection import train_test_split
from sksurv.linear_model import CoxnetSurvivalAnalysis, CoxPHSurvivalAnalysis
from sksurv.util import Surv
from sksurv.metrics import concordance_index_censored, concordance_index_ipcw, integrated_brier_score
from sklearn.model_selection import StratifiedKFold

def run_test_survival(K=5):
    cancer_types = ['GBM', 'HNSC', 'LUSC', 'LIHC', 'CESC', 'LUAD', 'KIRC', 'BRCA', 'LGG', 'OV', 'SKCM', 'THCA', 'BLCA', 'STAD', 'UCEC', 'COADREAD', 'COAD']  
    res_C_idx = pd.DataFrame(np.zeros((len(cancer_types), 1)), index=cancer_types, columns=['C-index'])
    for c_type in cancer_types:
        print(c_type)
        c_idx = []

        clinic_data = pd.read_csv('./TCGA_preprocessed/{}/clinic_data.csv'.format(c_type), header=0, index_col=0)
        clinic_data['merged_days'] = clinic_data["days_to_death"].fillna(clinic_data["days_to_last_followup"])
        indicator = (~clinic_data[['years_to_birth', 'gender']].isna().any(axis=1)) & (clinic_data['merged_days'] >= 0)
        samples = clinic_data.index[indicator]
        y = Surv.from_dataframe("vital_status", "merged_days", clinic_data.loc[samples])
        

        emb = pd.read_csv('./TCGA_results/{}/embeddings.csv'.format(c_type), index_col=0).loc[samples]
        features = clinic_data.loc[samples][['years_to_birth', 'gender']].join(emb)

        features = pd.get_dummies(features, drop_first=True).to_numpy() * 1.0
        kf = KFold(n_splits=K, shuffle=True)
        
        c_temp = 0.

        for train_idx, test_idx in kf.split(features):
            X_train, X_test = features[train_idx], features[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]
            model = CoxnetSurvivalAnalysis(l1_ratio=0.1, fit_baseline_model=True)

            model.fit(X_train, y_train)
            risk_scores = model.predict(X_test)
            c_temp += concordance_index_censored(y_test["vital_status"], y_test["merged_days"], risk_scores)[0]

        res_C_idx.loc[c_type] = c_temp/K
    return res_C_idx
    
res = run_test_survival(K=5)
print(res)
# Out:
# GBM
# HNSC
# LUSC
# LIHC
# CESC
# LUAD
# KIRC
# BRCA
# LGG
# OV
# SKCM
# THCA
# BLCA
# STAD
# UCEC
# COADREAD
# COAD
#            C-index
# GBM       0.640125
# HNSC      0.621491
# LUSC      0.536826
# LIHC      0.615794
# CESC      0.676878
# LUAD      0.595405
# KIRC      0.715703
# BRCA      0.673233
# LGG       0.841450
# OV        0.609655
# SKCM      0.650040
# THCA      0.892058
# BLCA      0.628860
# STAD      0.563993
# UCEC      0.629874
# COADREAD  0.573442
# COAD      0.518750

# %% [markdown]
# ## Downstreaming task 3: Clustering
# Here we partition the patients into a range of clusters (3-10) based on the output embeddings. For each cancer type and each number of clusters, we compute $-log_2(p)$, where $p$ is the $p$-value of a pairwise logrank test, using the survival status and estimated cluster membership of patients. Lower $p$ indicates stronger evidence of inter-cluster differences.

# %%
from lifelines.statistics import multivariate_logrank_test, pairwise_logrank_test
from lifelines import KaplanMeierFitter

cancer_types = ['GBM', 'HNSC', 'LUSC', 'LIHC', 'CESC', 'LUAD', 'KIRC', 'BRCA', 'LGG', 'OV', 'SKCM', 'THCA', 'BLCA', 'STAD', 'UCEC', 'COADREAD', 'COAD']  # do COAD seperately
my_range = range(3, 11)
res_logp_pair = pd.DataFrame(np.zeros((len(cancer_types), len(my_range))), index=cancer_types, columns=my_range)

for c_type in cancer_types:
    print(c_type)
    clinic_data = pd.read_csv('./TCGA_preprocessed/{}/clinic_data.csv'.format(c_type), header=0, index_col=0)
    clinic_data['merged_days'] = clinic_data["days_to_death"].fillna(clinic_data["days_to_last_followup"])
    indicator = (~clinic_data[['years_to_birth', 'gender']].isna().any(axis=1)) & (clinic_data['merged_days'] >= 0)
    samples = clinic_data.index[indicator]
    y = clinic_data.loc[samples][["vital_status", "merged_days"]]

    emb = pd.read_csv('./TCGA_results/{}/embeddings.csv'.format(c_type), index_col=0).loc[samples]
    for idx2, jjj in enumerate(my_range):
        kmeans = KMeans(n_clusters=jjj, n_init=20, random_state=314159)
        labels_pred = kmeans.fit_predict(emb)
        res_logp_pair.loc[c_type, jjj] = -1.*np.log2(pairwise_logrank_test(y['merged_days'], labels_pred, y['vital_status']).p_value.mean())
print(res_logp_pair)
# Out:
# GBM
# HNSC
# LUSC
# LIHC
# CESC
# LUAD
# KIRC
# BRCA
# LGG
# OV
# SKCM
# THCA
# BLCA
# STAD
# UCEC
# COADREAD
# COAD
#                 3         4         5         6         7         8   \
# GBM       5.468568  2.415752  2.453869  1.652026  1.954711  1.910928
# HNSC      3.159770  2.603318  2.614053  2.543306  2.373723  2.092139
# LUSC      2.954474  1.939171  2.179644  1.680865  1.494637  1.313886
# LIHC      1.232846  1.041398  1.546891  2.419295  1.588979  2.091966
# CESC      2.525748  1.757811  1.523754  1.625143  1.656757  1.417515
# LUAD      2.637015  1.856228  1.625765  1.685225  1.471031  1.728038
# KIRC      2.312045  1.978773  2.154344  2.702073  2.368248  1.861773
# BRCA      1.012320  4.246113  1.971604  2.177411  1.798338  2.024668
# LGG       5.040676  2.538890  2.628751  2.620503  2.342840  1.912463
# OV        0.725235  0.937297  1.229061  1.460342  1.550677  0.716696
# SKCM      5.950288  2.306732  2.324576  2.422261  2.151044  2.310080
# THCA      2.011360  1.252562  0.950964  2.173230  1.624340  1.370742
# BLCA      4.054120  3.143351  2.431957  2.372032  2.305813  2.027411
# STAD      1.376284  1.069674  1.398165  1.104577  0.962327  1.113019
# UCEC      5.327067  2.995215  1.983636  1.933108  2.141253  2.060281
# COADREAD  1.151760  1.642029  0.719061  1.001700  1.235032  1.048828
# COAD      0.203630  0.551108  1.147629  1.181343  1.045821  0.914021
#
#                 9         10
# GBM       1.779984  1.711342
# HNSC      2.123027  1.937398
# LUSC      1.517986  1.480153
# LIHC      1.628721  1.602407
# CESC      1.323286  1.384131
# LUAD      1.589099  1.520975
# KIRC      2.082692  2.000436
# BRCA      1.825806  1.555400
# LGG       1.728315  2.002010
# OV        1.164411  1.103512
# SKCM      2.236718  2.217388
# THCA      1.439257  1.324681
# BLCA      1.697116  2.247812
# STAD      1.091471  1.221074
# UCEC      1.845137  1.715107
# COADREAD  1.228012  1.335223
# COAD      0.730652  1.002115

# %% [markdown]
# ## Downstreaming task 4: Reconstruction
# We investiate how well does the proposed model reconstruct/predict the missing part of the training data. We frist re-train the model using masked versions of the multiomics datasets. The datasets are masked as follows: For each modality of each cancer type, we first randomly mask $10\%$ of its data subject to the constraint that, for every cancer type, each patient must be present in at least one modality of the resulting masked multiomics dataset. Once the models have been trained on the masked datasets, we predict the masked data using the learned embeddings, and compare the predictions with the observed values.

# %%
np.random.seed(31415)
torch.manual_seed(31415)

cancer_types = ['GBM', 'HNSC', 'LUSC', 'LIHC', 'LUAD', 'KIRC', 'BRCA', 'LGG', 'OV', 'PRAD', 'SKCM', 'THCA', 'BLCA', 'STAD', 'UCEC', 'COADREAD', 'COAD', 'CESC']  
for cancer_type in cancer_types:
    clinic_data = pd.read_csv('./TCGA_preprocessed/{}/clinic_data.csv'.format(cancer_type), header=0, index_col=0)
    RNA_data = pd.read_csv('./TCGA_preprocessed/{}/RNA_data_train.csv'.format(cancer_type), header=0, index_col=0)
    methyl_data = pd.read_csv('./TCGA_preprocessed/{}/methyl_data_train.csv'.format(cancer_type), header=0, index_col=0)
    rppa_data = pd.read_csv('./TCGA_preprocessed/{}/RPPA_data_train.csv'.format(cancer_type), header=0, index_col=0)
    cna_data = pd.read_csv('./TCGA_preprocessed/{}/CNA_data_train.csv'.format(cancer_type), header=0, index_col=0)
    if os.path.isfile('./TCGA_preprocessed/{}/miRNA_data_train.csv'.format(cancer_type)):
        miRNA_data = pd.read_csv('./TCGA_preprocessed/{}/miRNA_data_train.csv'.format(cancer_type), header=0, index_col=0)

    N = clinic_data.shape[0]
    print('Cancer type = {}'.format(cancer_type))
    print('total number of patients = {}'.format(N))
    if os.path.isfile('./TCGA_preprocessed/{}/miRNA_data_train.csv'.format(cancer_type)):
        data_dict = {'RNA': RNA_data, 'methyl': methyl_data, 'CNA': cna_data, 'miRNA': miRNA_data, 'RPPA': rppa_data}
    else:
        data_dict = {'RNA': RNA_data, 'methyl': methyl_data, 'CNA': cna_data, 'RPPA': rppa_data}

    for i, j in data_dict.items():
        print('{} data missing {}/{}, missing proportion = {}'.format(i, j.iloc[:, 0].isna().sum(), j.shape[0], np.round(j.iloc[:, 0].isna().mean(), 3)))

    presence_list = [torch.tensor(~_.isna().to_numpy().all(1)).to(device) for _ in list(data_dict.values())]
    data_list = [torch.tensor(_.to_numpy(), dtype=torch.float32).to(device) for _ in list(data_dict.values())]

    test = MIND(data_dict=data_dict, device=device, emb_dim=emb_dim).to(device)
    test.my_train(epoch, lr=lr)
    with torch.no_grad():
        z_emb = test.get_embedding()[0].cpu().numpy()

    # reconstructed version of the full dataset
    pred = test.predict()  
    # select the masked portion of data
    for i, nammme in enumerate(data_dict.keys()):
        test_obs = pd.read_csv('./TCGA_preprocessed/{}/{}_data_test.csv'.format(cancer_type, nammme), header=0, index_col=0)
        test_predicted = pd.DataFrame(pred[i].numpy(), index=RNA_data.index).loc[test_obs.index]
        test_predicted.to_csv('./TCGA_results/{}/{}_data_test_pred.csv'.format(cancer_type, nammme))
# Out:
# Cancer type = GBM
# total number of patients = 590
# RNA data missing 445/590, missing proportion = 0.754
# methyl data missing 331/590, missing proportion = 0.561
# CNA data missing 59/590, missing proportion = 0.1
# RPPA data missing 374/590, missing proportion = 0.634
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = HNSC
# total number of patients = 528
# RNA data missing 56/528, missing proportion = 0.106
# methyl data missing 51/528, missing proportion = 0.097
# CNA data missing 61/528, missing proportion = 0.116
# miRNA data missing 53/528, missing proportion = 0.1
# RPPA data missing 337/528, missing proportion = 0.638
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = LUSC
# total number of patients = 504
# RNA data missing 47/504, missing proportion = 0.093
# methyl data missing 169/504, missing proportion = 0.335
# CNA data missing 64/504, missing proportion = 0.127
# miRNA data missing 71/504, missing proportion = 0.141
# RPPA data missing 205/504, missing proportion = 0.407
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = LIHC
# total number of patients = 377
# RNA data missing 41/377, missing proportion = 0.109
# methyl data missing 36/377, missing proportion = 0.095
# CNA data missing 45/377, missing proportion = 0.119
# miRNA data missing 40/377, missing proportion = 0.106
# RPPA data missing 210/377, missing proportion = 0.557
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = LUAD
# total number of patients = 520
# RNA data missing 51/520, missing proportion = 0.098
# methyl data missing 104/520, missing proportion = 0.2
# CNA data missing 60/520, missing proportion = 0.115
# miRNA data missing 56/520, missing proportion = 0.108
# RPPA data missing 190/520, missing proportion = 0.365
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = KIRC
# total number of patients = 537
# RNA data missing 55/537, missing proportion = 0.102
# methyl data missing 247/537, missing proportion = 0.46
# CNA data missing 75/537, missing proportion = 0.14
# miRNA data missing 70/537, missing proportion = 0.13
# RPPA data missing 103/537, missing proportion = 0.192
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = BRCA
# total number of patients = 1097
# RNA data missing 105/1097, missing proportion = 0.096
# methyl data missing 380/1097, missing proportion = 0.346
# CNA data missing 127/1097, missing proportion = 0.116
# miRNA data missing 122/1097, missing proportion = 0.111
# RPPA data missing 292/1097, missing proportion = 0.266
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = LGG
# total number of patients = 515
# RNA data missing 48/515, missing proportion = 0.093
# methyl data missing 48/515, missing proportion = 0.093
# CNA data missing 52/515, missing proportion = 0.101
# miRNA data missing 54/515, missing proportion = 0.105
# RPPA data missing 127/515, missing proportion = 0.247
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = OV
# total number of patients = 590
# RNA data missing 314/590, missing proportion = 0.532
# methyl data missing 66/590, missing proportion = 0.112
# CNA data missing 78/590, missing proportion = 0.132
# miRNA data missing 181/590, missing proportion = 0.307
# RPPA data missing 210/590, missing proportion = 0.356
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = PRAD
# total number of patients = 498
# RNA data missing 49/498, missing proportion = 0.098
# methyl data missing 47/498, missing proportion = 0.094
# CNA data missing 51/498, missing proportion = 0.102
# miRNA data missing 52/498, missing proportion = 0.104
# RPPA data missing 178/498, missing proportion = 0.357
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = SKCM
# total number of patients = 470
# RNA data missing 43/470, missing proportion = 0.091
# methyl data missing 45/470, missing proportion = 0.096
# CNA data missing 138/470, missing proportion = 0.294
# miRNA data missing 63/470, missing proportion = 0.134
# RPPA data missing 151/470, missing proportion = 0.321
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = THCA
# total number of patients = 503
# RNA data missing 47/503, missing proportion = 0.093
# methyl data missing 48/503, missing proportion = 0.095
# CNA data missing 52/503, missing proportion = 0.103
# miRNA data missing 48/503, missing proportion = 0.095
# RPPA data missing 302/503, missing proportion = 0.6
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = BLCA
# total number of patients = 412
# RNA data missing 43/412, missing proportion = 0.104
# methyl data missing 40/412, missing proportion = 0.097
# CNA data missing 43/412, missing proportion = 0.104
# miRNA data missing 42/412, missing proportion = 0.102
# RPPA data missing 100/412, missing proportion = 0.243
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = STAD
# total number of patients = 443
# RNA data missing 64/443, missing proportion = 0.144
# methyl data missing 86/443, missing proportion = 0.194
# CNA data missing 46/443, missing proportion = 0.104
# miRNA data missing 48/443, missing proportion = 0.108
# RPPA data missing 120/443, missing proportion = 0.271
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = UCEC
# total number of patients = 548
# RNA data missing 56/548, missing proportion = 0.102
# methyl data missing 156/548, missing proportion = 0.285
# CNA data missing 74/548, missing proportion = 0.135
# miRNA data missing 60/548, missing proportion = 0.109
# RPPA data missing 149/548, missing proportion = 0.272
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = COADREAD
# total number of patients = 626
# RNA data missing 62/626, missing proportion = 0.099
# methyl data missing 273/626, missing proportion = 0.436
# CNA data missing 93/626, missing proportion = 0.149
# miRNA data missing 129/626, missing proportion = 0.206
# RPPA data missing 185/626, missing proportion = 0.296
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = COAD
# total number of patients = 457
# RNA data missing 42/457, missing proportion = 0.092
# methyl data missing 193/457, missing proportion = 0.422
# CNA data missing 49/457, missing proportion = 0.107
# miRNA data missing 87/457, missing proportion = 0.19
# RPPA data missing 134/457, missing proportion = 0.293
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000
# Cancer type = CESC
# total number of patients = 307
# RNA data missing 32/307, missing proportion = 0.104
# methyl data missing 28/307, missing proportion = 0.091
# CNA data missing 40/307, missing proportion = 0.13
# miRNA data missing 29/307, missing proportion = 0.094
# RPPA data missing 151/307, missing proportion = 0.492
# Epoch=0
# Epoch=1000
# Epoch=2000
# Epoch=3000
# Epoch=4000

# %%
cancer_types = ['GBM', 'HNSC', 'LUSC', 'LIHC', 'CESC', 'LUAD', 'KIRC', 'BRCA', 'LGG', 'OV', 'SKCM', 'THCA', 'BLCA', 'STAD', 'UCEC', 'COADREAD', 'COAD']  # do COAD seperately
mods = ['RNA', 'methyl', 'CNA', 'miRNA', 'RPPA']
res_corr = pd.DataFrame(np.zeros((len(cancer_types), 5)) * np.nan, index=cancer_types, columns=mods)
for cancer_type in cancer_types:
    for mod in mods:
        if os.path.isfile('./TCGA_preprocessed/{}/{}_data_test.csv'.format(cancer_type, mod)):
            pred = pd.read_csv('./TCGA_results/{}/{}_data_test_pred.csv'.format(cancer_type, mod), header=0, index_col=0).to_numpy().ravel()
            obs = pd.read_csv('./TCGA_preprocessed/{}/{}_data_test.csv'.format(cancer_type, mod), header=0, index_col=0).to_numpy().ravel()
            res_corr.loc[cancer_type, mod] = np.corrcoef(pred, obs)[0, 1]
            
print(res_corr)
# Out:
#                RNA    methyl       CNA     miRNA      RPPA
# GBM       0.283667  0.159389  0.304017       NaN  0.066223
# HNSC      0.340869  0.362852  0.221831  0.286871  0.077927
# LUSC      0.391946  0.347897  0.148169  0.249944  0.187262
# LIHC      0.444042  0.617602  0.350798  0.329479  0.345397
# CESC      0.301724  0.316541  0.240796  0.346496  0.144993
# LUAD      0.298295  0.356028  0.197201  0.290651  0.232931
# KIRC      0.498263  0.422525  0.379365  0.402921  0.261167
# BRCA      0.432397  0.420671  0.367710  0.421113  0.250354
# LGG       0.555975  0.558664  0.575640  0.411837  0.393617
# OV        0.210555  0.234810  0.310151  0.176573  0.093143
# SKCM      0.298319  0.389299  0.273702  0.228896  0.223381
# THCA      0.542357  0.254725  0.188864  0.322165  0.237826
# BLCA      0.410563  0.399036  0.182782  0.445897  0.261960
# STAD      0.284350  0.497969  0.279424  0.412589  0.286063
# UCEC      0.329905  0.413536  0.330754  0.394110  0.160096
# COADREAD  0.262425  0.295340  0.435800  0.287395  0.258261
# COAD      0.245121  0.355602  0.140100  0.370821  0.210129

# %%
print(res_corr.mean(1))
# Out:
# GBM         0.203324
# HNSC        0.258070
# LUSC        0.265044
# LIHC        0.417464
# CESC        0.270110
# LUAD        0.275021
# KIRC        0.392848
# BRCA        0.378449
# LGG         0.499147
# OV          0.205046
# SKCM        0.282719
# THCA        0.309187
# BLCA        0.340047
# STAD        0.352079
# UCEC        0.325680
# COADREAD    0.307844
# COAD        0.264355
# dtype: float64
